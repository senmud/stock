# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y1=np.cos(x)
plt.plot(x,y1)
plt.show()

# %%
import efinance as ef

stock_code = '002236'
series = ef.stock.get_base_info(stock_code)
series
# Out:
# 股票代码                  002236
# 股票名称                    大华股份
# 市盈率(动)                 14.99
# 市净率                     2.12
# 所处行业                   计算机设备
# 总市值       47942757187.300003
# 流通市值      30652552855.360004
# 板块编号                  BK0735
# ROE                    11.36
# 净利率                11.221717
# 净利润            2399047215.98
# 毛利率                 40.57219
# dtype: object

# %%
import efinance as ef

stock_code = '002236'
df = ef.stock.get_history_bill(stock_code)
df
# Out:
#      股票名称    股票代码          日期        主力净流入        小单净流入       中单净流入  \
# 0    大华股份  002236  2021-10-15  -30070108.0  -41310081.0  71380188.0
# 1    大华股份  002236  2021-10-18 -129581602.0   61471323.0  68110279.0
# 2    大华股份  002236  2021-10-19  -72749586.0   64874472.0   7875114.0
# 3    大华股份  002236  2021-10-20 -147672448.0  103390709.0  44281740.0
# 4    大华股份  002236  2021-10-21 -118060015.0   89597677.0  28462338.0
# ..    ...     ...         ...          ...          ...         ...
# 97   大华股份  002236  2022-03-09 -145358278.0  134810348.0  10547927.0
# 98   大华股份  002236  2022-03-10  -66585674.0   33297132.0  33288542.0
# 99   大华股份  002236  2022-03-11   12610322.0  -22029902.0   9419580.0
# 100  大华股份  002236  2022-03-14  -21403489.0   -4686549.0  26090039.0
# 101  大华股份  002236  2022-03-15   -3958560.0    7015265.0  -3056705.0
#
#            大单净流入       超大单净流入  主力净流入占比  小单流入净占比  中单流入净占比  大单流入净占比  超大单流入净占比  \
# ...

# %%
import efinance as ef
import time

stock_code = '600190'
today = time.strftime("%Y%m%d", time.localtime())
last_7days = time.strftime("%Y%m%d", time.localtime(time.time() - 7*86400))
df = ef.stock.get_quote_history(stock_code, beg=last_7days, end=today)
df
# Out:
#   股票名称    股票代码          日期    开盘    收盘    最高    最低      成交量           成交额  \
# 0  锦州港  600190  2022-03-09  4.50  4.73  4.73  4.50   747845  3.391098e+08
# 1  锦州港  600190  2022-03-10  4.60  4.98  5.18  4.32  1852805  8.842096e+08
# 2  锦州港  600190  2022-03-11  4.75  5.48  5.48  4.56  2065890  1.075493e+09
# 3  锦州港  600190  2022-03-14  4.93  4.93  5.23  4.93  1385061  6.928097e+08
# 4  锦州港  600190  2022-03-15  4.51  4.44  4.68  4.44   918702  4.111366e+08
# 5  锦州港  600190  2022-03-16  4.18  4.08  4.35  4.00   690548  2.851288e+08
#
#       振幅    涨跌幅   涨跌额    换手率
# 0   4.60  -5.40 -0.27   4.20
# 1  18.18   5.29  0.25  10.41
# 2  18.47  10.04  0.50  11.61
# 3   5.47 -10.04 -0.55   7.78
# 4   4.87  -9.94 -0.49   5.16
# 5   7.88  -8.11 -0.36   3.88

# %%
import efinance as ef

df = ef.stock.get_realtime_quotes()
df
# Out:
#         股票代码   股票名称    涨跌幅    最新价     最高     最低     今开    涨跌额    换手率    量比  \
# 0     603261    N立航  44.01  28.37  28.37  23.64  23.64   8.67    3.8     -
# 1     300649   杭州园林  20.01  34.12  34.12   28.0  28.19   5.69   25.5  1.84
# 2     301060   兰卫医学   20.0   51.9   51.9  40.66  40.98   8.65  62.22  1.98
# 3     300306   远方信息   20.0  16.86  16.86  14.92  14.92   2.81  29.53  3.14
# 4     300167    迪威迅  19.93   6.68   6.68   5.51   5.52   1.11  27.89   2.0
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 4913  300721   怡达股份 -16.62  39.09  44.78  37.88  44.78  -7.79   4.11  2.51
# 4914  301236    N软通 -16.85   60.6  71.65  58.08   59.0 -12.28  48.75     -
# 4915  688163   赛伦生物 -17.04  41.98  48.42  40.13   47.8  -8.62  42.66  0.66
# 4916  688256  寒武纪-U -18.38  66.02   78.5  64.98   78.5 -14.87   2.93  3.02
# 4917  301131   C聚赛龙 -22.38   60.0  69.97  59.88   68.0  -17.3  62.24  0.85
#
# ...

# %%
import efinance as ef

df = ef.stock.get_daily_billboard()
df
# Out:
#       股票代码  股票名称        上榜日期                   解读    收盘价      涨跌幅      换手率  \
# 0   000788  北大医药  2022-03-15     浙江资金买入，成功率28.20%  12.00   9.9908  18.2882
# 1   000788  北大医药  2022-03-15     浙江资金买入，成功率19.23%  12.00   9.9908  18.2882
# 2   000815   美利云  2022-03-15  西藏自治区资金买入，成功率15.12%  17.42   6.8056  25.1079
# 3   000815   美利云  2022-03-15   西藏自治区资金买入，成功率4.79%  17.42   6.8056  25.1079
# 4   000953  河化股份  2022-03-15     1家机构卖出，成功率36.52%   7.67  -9.9765  16.6572
# ..     ...   ...         ...                  ...    ...      ...      ...
# 66  605116   奥锐特  2022-03-15     实力游资买入，成功率38.23%  28.38  10.0000  31.9697
# 67  605116   奥锐特  2022-03-15       买一主买，成功率38.39%  28.38  10.0000  31.9697
# 68  688076  诺泰生物  2022-03-15     实力游资买入，成功率39.57%  43.15   4.5300  44.1180
# 69  688256   寒武纪  2022-03-15     1家机构卖出，成功率25.35%  66.02 -18.3830   2.9339
# 70  688687  凯因科技  2022-03-15     普通席位买入，成功率27.62%  21.97  15.2071  11.4677
#
# ...

# %%
import efinance as ef

df = ef.stock.get_realtime_quotes()
df
# Out:
#         股票代码   股票名称    涨跌幅    最新价     最高     最低     今开    涨跌额    换手率    量比  \
# 0     603261    N立航  44.01  28.37  28.37  23.64  23.64   8.67    3.8     -
# 1     300649   杭州园林  20.01  34.12  34.12   28.0  28.19   5.69   25.5  1.84
# 2     301060   兰卫医学   20.0   51.9   51.9  40.66  40.98   8.65  62.22  1.98
# 3     300306   远方信息   20.0  16.86  16.86  14.92  14.92   2.81  29.53  3.14
# 4     300167    迪威迅  19.93   6.68   6.68   5.51   5.52   1.11  27.89   2.0
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 4913  300721   怡达股份 -16.62  39.09  44.78  37.88  44.78  -7.79   4.11  2.51
# 4914  301236    N软通 -16.85   60.6  71.65  58.08   59.0 -12.28  48.75     -
# 4915  688163   赛伦生物 -17.04  41.98  48.42  40.13   47.8  -8.62  42.66  0.66
# 4916  688256  寒武纪-U -18.38  66.02   78.5  64.98   78.5 -14.87   2.93  3.02
# 4917  301131   C聚赛龙 -22.38   60.0  69.97  59.88   68.0  -17.3  62.24  0.85
#
# ...
