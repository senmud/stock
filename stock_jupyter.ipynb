# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,2*np.pi,0.01)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y1=np.cos(x)
plt.plot(x,y1)
plt.show()

# %%
import efinance as ef

stock_code = '002236'
series = ef.stock.get_base_info(stock_code)
series
df = ef.stock.get_quote_history(stock_code, beg='20181001', end='20210930')
df
df = ef.stock.get_history_bill(stock_code)
df
df = ef.stock.get_daily_billboard()
df
df = ef.stock.get_realtime_quotes()
df
# Out:
#         股票代码  股票名称     涨跌幅     最新价      最高     最低     今开    涨跌额    换手率    量比  \
# 0     301073   N君亭  133.99   28.64   32.98  27.71  30.25   16.4  70.99     -
# 1     301077   N星华   20.08    73.8    95.0  73.48   79.0  12.34  46.57     -
# 2     300514   友讯达   20.02   11.69   11.69   9.82   9.83   1.95   7.84  1.47
# 3     300830   金现代   20.01   16.07   16.07  14.01   14.5   2.68  31.27   2.0
# 4     688711  宏微科技    20.0  105.36  105.36   86.9   88.6  17.56  23.55  1.74
# ...      ...   ...     ...     ...     ...    ...    ...    ...    ...   ...
# 4668  600490  鹏欣资源   -7.93    4.99    5.49   4.88   4.88  -0.43  15.51  4.39
# 4669  300334  津膜科技   -8.23    10.6    12.1  10.11  11.98  -0.95   8.99  1.45
# 4670  002610  爱康科技   -9.74    4.45    4.74   4.44    4.6  -0.48  17.98  1.48
# 4671  301072   C中捷   -15.0   20.62   22.97   20.4   22.0  -3.64  51.67  0.76
# 4672  301075   C多瑞  -16.52   37.49    41.9  37.37  39.76  -7.42  36.46  0.77
#
#        动态市盈率      成交量           成交额   昨日收盘          总市值         流通市值  \
# 0      44.03   135351   408362640.0  12.24   2306665600    546066221
# 1      49.04    69848   559103248.0  61.46   4428000000   1107000000
# 2     247.16   119938   138953067.0   9.74   2338000000   1787541280
# 3     206.02   598054   915766544.0  13.39   6912108750   3073688813
# 4     163.23    47645   469374320.0   87.8  10377257670   2131858560
# ...      ...      ...           ...    ...          ...          ...
# 4668   89.77  3090737  1554787968.0   5.42  11042306524   9943180716
# 4669  162.84   268496   290426784.0  11.55   3201892774   3165236691
# 4670 -149.49  7881920  3581830800.0   4.93  19947970211  19512654149
# 4671   44.45   128693   274191856.0  24.26   2166229976    513562627
# 4672   40.45    72913   283602160.0  44.91   2999200000    749800000
#
#           行情ID 市场类型
# 0     0.301073   深A
# 1     0.301077   深A
# 2     0.300514   深A
# 3     0.300830   深A
# 4     1.688711   沪A
# ...        ...  ...
# 4668  1.600490   沪A
# 4669  0.300334   深A
# 4670  0.002610   深A
# 4671  0.301072   深A
# 4672  0.301075   深A
#
# [4673 rows x 18 columns]
